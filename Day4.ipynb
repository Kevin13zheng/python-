# %%
import numpy as np

A=np.random.randn(200,500)#创建一个从正太分布中返回的多个样本值组成的矩阵，行是200，列是500
B=np.random.randn(500,500)#创建一个从正太分布中返回的多个样本值组成的矩阵，行是500，列是500

def fun(l):
    return np.dot(A, np.dot(B,1*np.eye(500)))#创建B为拉普利兹矩阵，并将B与A相乘

res1 = A+A
res2 = np.dot(A,A.T)
res3 = np.dot(A.T,A)
res4 = np.dot(A,B)
l = int(input("lambda:"))
res5 = fun(l)
print(res1)
print(res2)
print(res3)
print(res4)
print(res5)
# Out:
# lambda:1
# [[ 0.21706442  0.67254353  1.32907686 ... -3.07583982 -3.75280654
#    1.02707893]
#  [-1.80340022  3.83774539 -0.68346988 ... -0.62627127 -1.64348258
#    0.24568201]
#  [ 2.14965286 -2.05924546 -1.2390096  ... -1.5987167  -0.92069837
#    0.98966354]
#  ...
#  [-1.29978899  1.67907493 -1.63331169 ...  3.59135237 -0.15953705
#   -0.00684869]
#  [-0.07914295 -2.29410356 -2.20279336 ...  0.79755487 -0.8718653
#   -3.42417957]
#  [ 0.0339119   1.88903662 -0.38958788 ... -3.74642155 -1.56093664
#    0.44980869]]
# [[518.48436765  -7.18058217  31.23769972 ... -24.31045668 -33.7014024
#   -27.27125421]
#  [ -7.18058217 506.95176109 -13.05003825 ... -19.42036813  -4.2848712
#     1.21595146]
#  [ 31.23769972 -13.05003825 481.41245749 ...  30.86066771 -22.47454243
#     8.56319891]
#  ...
#  [-24.31045668 -19.42036813  30.86066771 ... 498.94395905 -37.34975483
#    33.51284741]
#  [-33.7014024   -4.2848712  -22.47454243 ... -37.34975483 468.50471534
#    25.51697576]
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

def fun(x):
    return np.dot(k,v)
v = int(input("lambda:"))
k = np.arange(-10, 10)
y = 2*x
y1 = -x + 3

plt.figure()
plt.plot(x,y)
plt.plot(x,y1)
plt.xlim(0,10)
plt.ylim(0,10)
# draw axes
plt.axvline(x=0, color='grey')
plt.axhline(y=0, color='grey')
plt.show()
plt.close()
# Out:
# lambda:0.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-ca1104d3325c> in <module>
#       4 def fun(x):
#       5     return np.dot(k,v)
# ----> 6 v = int(input("lambda:"))
#       7 k = np.arange(-10, 10)
#       8 y = 2*x
#
# ValueError: invalid literal for int() with base 10: '0.5'
